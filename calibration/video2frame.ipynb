# %% [markdown]
# # Extract frames from video

# %%
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture("./IMG_0533.mov") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('data'): 
        os.makedirs('data') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './data/frame' + str(currentframe) + '.png'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        frame = cv2.rotate(frame, cv2.ROTATE_180) 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../data/frame0.png
# Creating..../data/frame1.png
# Creating..../data/frame2.png
# Creating..../data/frame3.png
# Creating..../data/frame4.png
# Creating..../data/frame5.png
# Creating..../data/frame6.png
# Creating..../data/frame7.png
# Creating..../data/frame8.png
# Creating..../data/frame9.png
# Creating..../data/frame10.png
# Creating..../data/frame11.png
# Creating..../data/frame12.png
# Creating..../data/frame13.png
# Creating..../data/frame14.png
# Creating..../data/frame15.png
# Creating..../data/frame16.png
# Creating..../data/frame17.png
# Creating..../data/frame18.png
# Creating..../data/frame19.png
# Creating..../data/frame20.png
# Creating..../data/frame21.png
# Creating..../data/frame22.png
# Creating..../data/frame23.png
# Creating..../data/frame24.png
# Creating..../data/frame25.png
# Creating..../data/frame26.png
# Creating..../data/frame27.png
# Creating..../data/frame28.png
# Creating..../data/frame29.png
# Creating..../data/frame30.png
# Creating..../data/frame31.png
# Creating..../data/frame32.png
# Creating..../data/frame33.png
# Creating..../data/frame34.png
# Creating..../data/frame35.png
# Creating..../data/frame36.png
# Creating..../data/frame37.png
# Creating..../data/frame38.png
# Creating..../data/frame39.png
# Creating..../data/frame40.png
# Creating..../data/frame41.png
# Creating..../data/frame42.png
# Creating..../data/frame43.png
# Creating..../data/frame44.png
# Creating..../data/frame45.png
# Creating..../data/frame46.png
# Creating..../data/frame47.png
# Creating..../data/frame48.png
# Creating..../data/frame49.png
# Creating..../data/frame50.png
# Creating..../data/frame51.png
# Creating..../data/frame52.png
# Creating..../data/frame53.png
# Creating..../data/frame54.png
# Creating..../data/frame55.png
# Creating..../data/frame56.png
# Creating..../data/frame57.png
# Creating..../data/frame58.png
# Creating..../data/frame59.png
# Creating..../data/frame60.png
# Creating..../data/frame61.png
# Creating..../data/frame62.png
# Creating..../data/frame63.png
# Creating..../data/frame64.png
# Creating..../data/frame65.png
# Creating..../data/frame66.png
# Creating..../data/frame67.png
# Creating..../data/frame68.png
# Creating..../data/frame69.png
# Creating..../data/frame70.png
# Creating..../data/frame71.png
# Creating..../data/frame72.png
# Creating..../data/frame73.png
# Creating..../data/frame74.png
# Creating..../data/frame75.png
# Creating..../data/frame76.png
# Creating..../data/frame77.png
# Creating..../data/frame78.png
# Creating..../data/frame79.png
# Creating..../data/frame80.png
# Creating..../data/frame81.png
# Creating..../data/frame82.png
# Creating..../data/frame83.png
# Creating..../data/frame84.png
# Creating..../data/frame85.png
# Creating..../data/frame86.png
# Creating..../data/frame87.png
# Creating..../data/frame88.png
# Creating..../data/frame89.png
# Creating..../data/frame90.png
# Creating..../data/frame91.png
# Creating..../data/frame92.png
# Creating..../data/frame93.png
# Creating..../data/frame94.png
# Creating..../data/frame95.png
# Creating..../data/frame96.png
# Creating..../data/frame97.png
# Creating..../data/frame98.png
# Creating..../data/frame99.png
# Creating..../data/frame100.png
# Creating..../data/frame101.png
# Creating..../data/frame102.png
# Creating..../data/frame103.png
# Creating..../data/frame104.png
# Creating..../data/frame105.png
# Creating..../data/frame106.png
# Creating..../data/frame107.png
# Creating..../data/frame108.png
# Creating..../data/frame109.png
# Creating..../data/frame110.png
# Creating..../data/frame111.png
# Creating..../data/frame112.png
# Creating..../data/frame113.png
# Creating..../data/frame114.png
# Creating..../data/frame115.png
# Creating..../data/frame116.png
# Creating..../data/frame117.png
# Creating..../data/frame118.png
# Creating..../data/frame119.png
# Creating..../data/frame120.png
# Creating..../data/frame121.png
# Creating..../data/frame122.png
# Creating..../data/frame123.png
# Creating..../data/frame124.png
